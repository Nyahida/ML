# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
# %matplotlib inline

# %%
telco_data=pd.read_csv('Churn_Modelling.csv')

# %%
telco_data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
telco_new=telco_data[['Geography','Gender','Exited']]

# %%
telco_new
# Out:
#      Geography  Gender  Exited
# 0       France  Female       1
# 1        Spain  Female       0
# 2       France  Female       1
# 3       France  Female       0
# 4        Spain  Female       0
# ...        ...     ...     ...
# 9995    France    Male       0
# 9996    France    Male       0
# 9997    France  Female       1
# 9998   Germany    Male       1
# 9999    France  Female       0
#
# [10000 rows x 3 columns]

# %% [markdown]
# ### Univariate Analysis

# %%
for i,predictor in enumerate(telco_new.drop(columns=['Exited'])):
    plt.figure()
    sns.countplot(data=telco_new,x=predictor,hue='Exited')

# %%
telco_new.Exited.value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
telco_new.Exited.value_counts()/len(telco_new)*100
# Out:
# Exited
# 0    79.63
# 1    20.37
# Name: count, dtype: float64

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.histplot(x='Gender',hue='Geography',data=telco_new,stat='count',multiple='dodge')
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %%
telco_new_target1=telco_new.loc[telco_new['Exited']==1]

# %%
sns.histplot(x='Gender',hue='Geography',data=telco_new_target1,stat='count',multiple='dodge')
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %% [markdown]
# ### Numerical Analysis

# %% [markdown]
# ##### Correlation:It ranges from -1 to +1
# ##### +1--->Positive Correlation -1--->Negative Correlation  0-->No Correlation

# %%
telco_data.corr(numeric_only=True)
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
plt.figure(figsize=(20,8))
telco_data.corr(numeric_only=True)['Exited'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: >

# %%
telco_data.corr(numeric_only=True)

# %%
plt.figure(figsize=(6,5))
sns.heatmap(telco_data.corr(numeric_only=True),cmap='Paired')
# Out:
# <Axes: >

# %%
telco_data.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
telco_data['Age'].value_counts().sort_index(ascending=True).plot()
# Out:
# <Axes: xlabel='Age'>

# %%
telco_data_1=telco_data.loc[telco_data['Exited']==1]

# %%
telco_data_1['Age'].value_counts().sort_index(ascending=True).plot()
# Out:
# <Axes: xlabel='Age'>

# %%
Tot=sns.kdeplot(telco_data.Age[(telco_data['Exited']==0)],color='green',shade=True)
Tot=sns.kdeplot(telco_data.Age[(telco_data['Exited']==1)],color='red',shade=True)
Tot.legend(['No Churn','Churn'],loc='upper right')
Tot.set_xlabel('Age')
Tot.set_ylabel('Density')
Tot.set_title('Age by churn')
# Out:
# C:\Users\enter\AppData\Local\Temp\ipykernel_11648\1499490190.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Tot=sns.kdeplot(telco_data.Age[(telco_data['Exited']==0)],color='green',shade=True)
# C:\Users\enter\AppData\Local\Temp\ipykernel_11648\1499490190.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Tot=sns.kdeplot(telco_data.Age[(telco_data['Exited']==1)],color='red',shade=True)
# Text(0.5, 1.0, 'Age by churn')

# %%
Tot=sns.kdeplot(telco_data.CreditScore[(telco_data['Exited']==0)],color='green',shade=True)
Tot=sns.kdeplot(telco_data.CreditScore[(telco_data['Exited']==1)],color='red',shade=True)
Tot.legend(['No Churn','Churn'],loc='upper right')
Tot.set_xlabel('Credit Score')
Tot.set_ylabel('Density')
Tot.set_title('Credit Score by churn')
# Out:
# C:\Users\enter\AppData\Local\Temp\ipykernel_11648\439015751.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Tot=sns.kdeplot(telco_data.CreditScore[(telco_data['Exited']==0)],color='green',shade=True)
# C:\Users\enter\AppData\Local\Temp\ipykernel_11648\439015751.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Tot=sns.kdeplot(telco_data.CreditScore[(telco_data['Exited']==1)],color='red',shade=True)
# Text(0.5, 1.0, 'Credit Score by churn')

# %%
Tot=sns.kdeplot(telco_data.Balance[(telco_data['Exited']==0)],color='green',shade=True)
Tot=sns.kdeplot(telco_data.Balance[(telco_data['Exited']==1)],color='red',shade=True)
Tot.legend(['No Churn','Churn'],loc='upper right')
Tot.set_xlabel('Balance')
Tot.set_ylabel('Density')
Tot.set_title('Balance by churn')
# Out:
# C:\Users\enter\AppData\Local\Temp\ipykernel_11648\1117816784.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Tot=sns.kdeplot(telco_data.Balance[(telco_data['Exited']==0)],color='green',shade=True)
# C:\Users\enter\AppData\Local\Temp\ipykernel_11648\1117816784.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Tot=sns.kdeplot(telco_data.Balance[(telco_data['Exited']==1)],color='red',shade=True)
# Text(0.5, 1.0, 'Balance by churn')

# %%
sns.histplot(x='Age',data=telco_data,bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>
